# %% [markdown]
# <h1 style="color: #6E9D8C ;"> * * * Final Project</h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h1 style="color: #6E9D8C ;"> * * * Work</h1>

# %% [markdown]
# <h1 style="color: #6E9D8C ;"> * I * Data Extraction</h1>

# %%
# Read the Excel file
data = pd.read_excel(r"C:\Users\ggsan\Desktop\Ironhack\2. LABS\9.WEEK_Lab\reservations_data.xlsx")

# Display the first few rows of the dataframe
data.head()
# Out:
#      Lista de reservas  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0       Reservation ID  Resv Date   Resv Satus    Check-in   Check-out
# 1  A169-2511331136-465  08-08-2023        Paga  11-08-2023  13-08-2023
# 2  A169-3087875980-637  11-05-2022        Paga  03-06-2022  04-06-2022
# 3  A169-3285564121-828  15-05-2022        Paga  21-08-2022  24-08-2022
# 4  A169-3703768823-172  11-03-2023        Paga  17-03-2023  18-03-2023
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0         RN     Total     Adultos   Crianças      Bebés   Room Type
# 1          2     557.85          4          0          0          T1
# 2          1      68.38          2          0          0          T1
# 3          3     631.05          4          0          0          T3
# 4          1      48.26          2          0          0          T0
#
#      Unnamed: 11          Unnamed: 12        Unnamed: 13    Unnamed: 14  \
# 0  id alojamento  Cliente: Id cliente              Guest  Cliente: País
# 1         328927             16843014  Lista de reservas  África do Sul
# 2         328970              9602155   John Doe 9602155  África do Sul
# 3         328588              9646746   John Doe 9646746  África do Sul
# 4         328947             13951562  Lista de reservas  África do Sul
#
#      Unnamed: 15                 Unnamed: 16  Unnamed: 17 Unnamed: 18  \
# 0  Hóspede: País  Hóspede: Idioma do cliente       Portal    Comments
# 1            NaN                     Francês  Booking.com         NaN
# 2  África do Sul                 Inglês (UK)  Booking.com         NaN
# 3  África do Sul                 Inglês (UK)  Booking.com         NaN
# 4  África do Sul                 Inglês (UK)  Booking.com         NaN
#
#   Unnamed: 19
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# <h3 style="color: #7E5564;"> - Exploring the Data (First Impression)</h3>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19463 entries, 0 to 19462
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Lista de reservas  19463 non-null  object
#  1   Unnamed: 1         19463 non-null  object
#  2   Unnamed: 2         19463 non-null  object
#  3   Unnamed: 3         19463 non-null  object
#  4   Unnamed: 4         19463 non-null  object
#  5   Unnamed: 5         19463 non-null  object
#  6   Unnamed: 6         19463 non-null  object
#  7   Unnamed: 7         19463 non-null  object
#  8   Unnamed: 8         19463 non-null  object
#  9   Unnamed: 9         16903 non-null  object
#  10  Unnamed: 10        19463 non-null  object
#  11  Unnamed: 11        19463 non-null  object
#  12  Unnamed: 12        17688 non-null  object
#  13  Unnamed: 13        19463 non-null  object
#  14  Unnamed: 14        17635 non-null  object
#  15  Unnamed: 15        16074 non-null  object
#  16  Unnamed: 16        16361 non-null  object
#  17  Unnamed: 17        15870 non-null  object
#  18  Unnamed: 18        984 non-null    object
#  19  Unnamed: 19        2151 non-null   object
# dtypes: object(20)
# memory usage: 3.0+ MB

# %%
data.columns = [''] * len(data.columns)
data.head()
# Out:
#                                                                             \
# 0       Reservation ID  Resv Date   Resv Satus    Check-in   Check-out  RN
# 1  A169-2511331136-465  08-08-2023        Paga  11-08-2023  13-08-2023   2
# 2  A169-3087875980-637  11-05-2022        Paga  03-06-2022  04-06-2022   1
# 3  A169-3285564121-828  15-05-2022        Paga  21-08-2022  24-08-2022   3
# 4  A169-3703768823-172  11-03-2023        Paga  17-03-2023  18-03-2023   1
#
#                                                                \
# 0  Total   Adultos  Crianças  Bebés  Room Type  id alojamento
# 1  557.85        4         0      0         T1         328927
# 2   68.38        2         0      0         T1         328970
# 3  631.05        4         0      0         T3         328588
# 4   48.26        2         0      0         T0         328947
#
#                                                                          \
# 0  Cliente: Id cliente              Guest  Cliente: País  Hóspede: País
# 1             16843014  Lista de reservas  África do Sul            NaN
# 2              9602155   John Doe 9602155  África do Sul  África do Sul
# 3              9646746   John Doe 9646746  África do Sul  África do Sul
# 4             13951562  Lista de reservas  África do Sul  África do Sul
#
#
# 0  Hóspede: Idioma do cliente       Portal  Comments  NaN
# 1                     Francês  Booking.com       NaN  NaN
# 2                 Inglês (UK)  Booking.com       NaN  NaN
# 3                 Inglês (UK)  Booking.com       NaN  NaN
# 4                 Inglês (UK)  Booking.com       NaN  NaN

# %%
data.columns = [
    'resv_id', 'Resv Date', 'Resv Status', 'Check-in', 'Check-out', 'RN', 
    'Resv Total', 'Adults', 'Child', 'Baby', 'Room Type', 
    'Id RoomType', 'Id client', 'Guest', 'Client: Country', 'Guest: Country', 
    'Guest: Language', 'Distribuition', 'OOS', 'Other'
]
data.head()
# Out:
#                resv_id   Resv Date Resv Status    Check-in   Check-out  RN  \
# 0       Reservation ID  Resv Date   Resv Satus    Check-in   Check-out  RN
# 1  A169-2511331136-465  08-08-2023        Paga  11-08-2023  13-08-2023   2
# 2  A169-3087875980-637  11-05-2022        Paga  03-06-2022  04-06-2022   1
# 3  A169-3285564121-828  15-05-2022        Paga  21-08-2022  24-08-2022   3
# 4  A169-3703768823-172  11-03-2023        Paga  17-03-2023  18-03-2023   1
#
#   Resv Total   Adults     Child   Baby  Room Type    Id RoomType  \
# 0     Total   Adultos  Crianças  Bebés  Room Type  id alojamento
# 1     557.85        4         0      0         T1         328927
# 2      68.38        2         0      0         T1         328970
# 3     631.05        4         0      0         T3         328588
# 4      48.26        2         0      0         T0         328947
#
#              Id client              Guest Client: Country Guest: Country  \
# 0  Cliente: Id cliente              Guest   Cliente: País  Hóspede: País
# 1             16843014  Lista de reservas   África do Sul            NaN
# 2              9602155   John Doe 9602155   África do Sul  África do Sul
# 3              9646746   John Doe 9646746   África do Sul  África do Sul
# 4             13951562  Lista de reservas   África do Sul  África do Sul
#
#               Guest: Language Distribuition       OOS Other
# 0  Hóspede: Idioma do cliente        Portal  Comments   NaN
# 1                     Francês   Booking.com       NaN   NaN
# 2                 Inglês (UK)   Booking.com       NaN   NaN
# 3                 Inglês (UK)   Booking.com       NaN   NaN
# 4                 Inglês (UK)   Booking.com       NaN   NaN

# %%
# Strip spaces from column names
data.columns = data.columns.str.strip()

# Skip the first row when converting to datetime
data[['Resv Date', 'Check-in', 'Check-out']] = data[['Resv Date', 'Check-in', 'Check-out']].iloc[1:].apply(pd.to_datetime, dayfirst=True)

# %% [markdown]
# <h3 style="color: #7E5564;"> - Column standardization</h3>

# %%
data.columns = [column.replace(':', '').replace('-', '') for column in data.columns]

# %%
data.columns = [column.lower().replace(' ', '_') for column in data.columns]

# %%
data.head()
# Out:
#                resv_id  resv_date resv_status    checkin   checkout  rn  \
# 0       Reservation ID        NaT  Resv Satus        NaT        NaT  RN
# 1  A169-2511331136-465 2023-08-08        Paga 2023-08-11 2023-08-13   2
# 2  A169-3087875980-637 2022-05-11        Paga 2022-06-03 2022-06-04   1
# 3  A169-3285564121-828 2022-05-15        Paga 2022-08-21 2022-08-24   3
# 4  A169-3703768823-172 2023-03-11        Paga 2023-03-17 2023-03-18   1
#
#   resv_total   adults     child   baby  room_type    id_roomtype  \
# 0     Total   Adultos  Crianças  Bebés  Room Type  id alojamento
# 1     557.85        4         0      0         T1         328927
# 2      68.38        2         0      0         T1         328970
# 3     631.05        4         0      0         T3         328588
# 4      48.26        2         0      0         T0         328947
#
#              id_client              guest client_country  guest_country  \
# 0  Cliente: Id cliente              Guest  Cliente: País  Hóspede: País
# 1             16843014  Lista de reservas  África do Sul            NaN
# 2              9602155   John Doe 9602155  África do Sul  África do Sul
# 3              9646746   John Doe 9646746  África do Sul  África do Sul
# 4             13951562  Lista de reservas  África do Sul  África do Sul
#
#                guest_language distribuition       oos other
# 0  Hóspede: Idioma do cliente        Portal  Comments   NaN
# 1                     Francês   Booking.com       NaN   NaN
# 2                 Inglês (UK)   Booking.com       NaN   NaN
# 3                 Inglês (UK)   Booking.com       NaN   NaN
# 4                 Inglês (UK)   Booking.com       NaN   NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19463 entries, 0 to 19462
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   resv_id         19463 non-null  object
#  1   resv_date       19462 non-null  datetime64[ns]
#  2   resv_status     19463 non-null  object
#  3   checkin         19462 non-null  datetime64[ns]
#  4   checkout        19462 non-null  datetime64[ns]
#  5   rn              19463 non-null  object
#  6   resv_total      19463 non-null  object
#  7   adults          19463 non-null  object
#  8   child           19463 non-null  object
#  9   baby            16903 non-null  object
#  10  room_type       19463 non-null  object
#  11  id_roomtype     19463 non-null  object
#  12  id_client       17688 non-null  object
#  13  guest           19463 non-null  object
#  14  client_country  17635 non-null  object
#  15  guest_country   16074 non-null  object
#  16  guest_language  16361 non-null  object
#  17  distribuition   15870 non-null  object
#  18  oos             984 non-null    object
#  19  other           2151 non-null   object
# dtypes: datetime64[ns](3), object(17)
# memory usage: 3.0+ MB

# %%
data.dtypes
# Out:
# resv_id                   object
# resv_date         datetime64[ns]
# resv_status               object
# checkin           datetime64[ns]
# checkout          datetime64[ns]
# rn                        object
# resv_total                object
# adults                    object
# child                     object
# baby                      object
# room_type                 object
# id_roomtype               object
# id_client                 object
# guest                     object
# client_country            object
# guest_country             object
# guest_language            object
# distribuition             object
# oos                       object
# other                     object
# dtype: object

# %%
# Convert specified columns to integers
columns_to_convert = ['rn', 'adults', 'child', 'baby', 'id_roomtype', 'id_client']
data[columns_to_convert] = data[columns_to_convert].apply(pd.to_numeric, errors='coerce').astype('Int64')

data.dtypes
# Out:
# resv_id                   object
# resv_date         datetime64[ns]
# resv_status               object
# checkin           datetime64[ns]
# checkout          datetime64[ns]
# rn                         Int64
# resv_total                object
# adults                     Int64
# child                      Int64
# baby                       Int64
# room_type                 object
# id_roomtype                Int64
# id_client                  Int64
# guest                     object
# client_country            object
# guest_country             object
# guest_language            object
# distribuition             object
# oos                       object
# other                     object
# dtype: object

# %%
data.head()
# Out:
#                resv_id  resv_date resv_status    checkin   checkout    rn  \
# 0       Reservation ID        NaT  Resv Satus        NaT        NaT  <NA>
# 1  A169-2511331136-465 2023-08-08        Paga 2023-08-11 2023-08-13     2
# 2  A169-3087875980-637 2022-05-11        Paga 2022-06-03 2022-06-04     1
# 3  A169-3285564121-828 2022-05-15        Paga 2022-08-21 2022-08-24     3
# 4  A169-3703768823-172 2023-03-11        Paga 2023-03-17 2023-03-18     1
#
#   resv_total  adults  child  baby  room_type  id_roomtype  id_client  \
# 0     Total     <NA>   <NA>  <NA>  Room Type         <NA>       <NA>
# 1     557.85       4      0     0         T1       328927   16843014
# 2      68.38       2      0     0         T1       328970    9602155
# 3     631.05       4      0     0         T3       328588    9646746
# 4      48.26       2      0     0         T0       328947   13951562
#
#                guest client_country  guest_country  \
# 0              Guest  Cliente: País  Hóspede: País
# 1  Lista de reservas  África do Sul            NaN
# 2   John Doe 9602155  África do Sul  África do Sul
# 3   John Doe 9646746  África do Sul  África do Sul
# 4  Lista de reservas  África do Sul  África do Sul
#
#                guest_language distribuition       oos other
# 0  Hóspede: Idioma do cliente        Portal  Comments   NaN
# 1                     Francês   Booking.com       NaN   NaN
# 2                 Inglês (UK)   Booking.com       NaN   NaN
# 3                 Inglês (UK)   Booking.com       NaN   NaN
# 4                 Inglês (UK)   Booking.com       NaN   NaN

# %%
data = data.drop(index=0).reset_index(drop=True)
data.head()
# Out:
#                resv_id  resv_date resv_status    checkin   checkout  rn  \
# 0  A169-2511331136-465 2023-08-08        Paga 2023-08-11 2023-08-13   2
# 1  A169-3087875980-637 2022-05-11        Paga 2022-06-03 2022-06-04   1
# 2  A169-3285564121-828 2022-05-15        Paga 2022-08-21 2022-08-24   3
# 3  A169-3703768823-172 2023-03-11        Paga 2023-03-17 2023-03-18   1
# 4  A169-4048298901-301 2023-09-25        Paga 2023-09-26 2023-09-30   4
#
#   resv_total  adults  child  baby room_type  id_roomtype  id_client  \
# 0     557.85       4      0     0        T1       328927   16843014
# 1      68.38       2      0     0        T1       328970    9602155
# 2     631.05       4      0     0        T3       328588    9646746
# 3      48.26       2      0     0        T0       328947   13951562
# 4     255.09       1      0     0        T0       328957   17813842
#
#                guest client_country  guest_country guest_language  \
# 0  Lista de reservas  África do Sul            NaN        Francês
# 1   John Doe 9602155  África do Sul  África do Sul    Inglês (UK)
# 2   John Doe 9646746  África do Sul  África do Sul    Inglês (UK)
# 3  Lista de reservas  África do Sul  África do Sul    Inglês (UK)
# 4  Lista de reservas  África do Sul  África do Sul    Inglês (UK)
#
#   distribuition  oos other
# 0   Booking.com  NaN   NaN
# 1   Booking.com  NaN   NaN
# 2   Booking.com  NaN   NaN
# 3   Booking.com  NaN   NaN
# 4   Booking.com  NaN   NaN

# %%
data.describe().T
# Out:
#                count                           mean                  min  \
# resv_date      19462  2022-09-19 17:09:25.656150528  1900-01-01 00:00:00
# checkin        19462  2022-12-05 03:44:46.959202560  2020-08-08 00:00:00
# checkout       19462     2022-12-11 23:22:24.774432  2020-08-15 00:00:00
# rn           19462.0                       6.817799                  1.0
# adults       19462.0                       1.951444                  1.0
# child        19462.0                       0.136266                  0.0
# baby         16902.0                       0.002958                  0.0
# id_roomtype  19462.0                  331143.653992             328528.0
# id_client    17687.0                10226326.439758              91089.0
#
#                              25%                  50%                  75%  \
# resv_date    2022-03-23 00:00:00  2022-12-06 00:00:00  2023-04-27 00:00:00
# checkin      2022-06-01 00:00:00  2023-01-03 00:00:00  2023-08-05 00:00:00
# checkout     2022-06-06 00:00:00  2023-01-09 00:00:00  2023-08-12 00:00:00
# rn                           2.0                  4.0                  7.0
# adults                       1.0                  2.0                  2.0
# child                        0.0                  0.0                  0.0
# baby                         0.0                  0.0                  0.0
# id_roomtype             328885.0             328929.0             328957.0
# id_client              6270764.0            9759568.0           13778276.0
#
#                              max             std
# resv_date    2024-01-30 00:00:00             NaN
# checkin      2024-10-27 00:00:00             NaN
# checkout     2025-02-13 00:00:00             NaN
# rn                         491.0       16.235874
# adults                      12.0        1.308393
# child                        6.0        0.528351
# baby                         2.0        0.059509
# id_roomtype             440318.0    14090.231495
# id_client             19694730.0  5050969.015361

# %% [markdown]
# <h3 style="color: #7E5564;"> - Copy as best practices</h3>

# %%
df1 = data.copy()
df1.head()
# Out:
#                resv_id  resv_date resv_status    checkin   checkout  rn  \
# 0  A169-2511331136-465 2023-08-08        Paga 2023-08-11 2023-08-13   2
# 1  A169-3087875980-637 2022-05-11        Paga 2022-06-03 2022-06-04   1
# 2  A169-3285564121-828 2022-05-15        Paga 2022-08-21 2022-08-24   3
# 3  A169-3703768823-172 2023-03-11        Paga 2023-03-17 2023-03-18   1
# 4  A169-4048298901-301 2023-09-25        Paga 2023-09-26 2023-09-30   4
#
#   resv_total  adults  child  baby room_type  id_roomtype  id_client  \
# 0     557.85       4      0     0        T1       328927   16843014
# 1      68.38       2      0     0        T1       328970    9602155
# 2     631.05       4      0     0        T3       328588    9646746
# 3      48.26       2      0     0        T0       328947   13951562
# 4     255.09       1      0     0        T0       328957   17813842
#
#                guest client_country  guest_country guest_language  \
# 0  Lista de reservas  África do Sul            NaN        Francês
# 1   John Doe 9602155  África do Sul  África do Sul    Inglês (UK)
# 2   John Doe 9646746  África do Sul  África do Sul    Inglês (UK)
# 3  Lista de reservas  África do Sul  África do Sul    Inglês (UK)
# 4  Lista de reservas  África do Sul  África do Sul    Inglês (UK)
#
#   distribuition  oos other
# 0   Booking.com  NaN   NaN
# 1   Booking.com  NaN   NaN
# 2   Booking.com  NaN   NaN
# 3   Booking.com  NaN   NaN
# 4   Booking.com  NaN   NaN

# %% [markdown]
# <h3 style="color: #7E5564;"> - Copy to EDA project</h3>

# %%
df2 = data.copy()
df2.oos.value_counts()
# Out:
# oos
# m              539
# h              344
# a               48
# t               46
# ADM              2
# Overbooking      1
# maintenance      1
# team             1
# hk               1
# Name: count, dtype: int64

# %% [markdown]
# <h1 style="color: #6E9D8C;"> * II * Data Cleaning</h1>

# %%
df1['other'].value_counts()
# Out:
# other
# Reembolsável    2151
# Name: count, dtype: int64

# %%
df1['oos'].value_counts()
# Out:
# oos
# m              539
# h              344
# a               48
# t               46
# ADM              2
# Overbooking      1
# maintenance      1
# team             1
# hk               1
# Name: count, dtype: int64

# %%
df1['resv_status'].value_counts()
# Out:
# resv_status
# Paga                         9272
# Cancelada                    7206
# De proprietário              1341
# Pré-reserva                   966
# Indisponível                  402
# Confirmada                    250
# Pedido informação              12
# Sob pedido                     10
# Pedido de disponibilidade       2
# Garantia                        1
# Name: count, dtype: int64

# %%
df1['guest_language'].value_counts()
# Out:
# guest_language
# Português (PT)    8402
# Inglês (UK)       3939
# Espanhol (ES)     1822
# Francês            839
# Italian            296
# Alemão             276
# Holandês           231
# Portugues (BR)     161
# Inglês (US)         83
# Polish              74
# Swedish             59
# Russo               43
# Norueguês           35
# Dinamarquês         34
# Czech               29
# Español (MX)        19
# Hungarian            9
# Korean               4
# Japanese             2
# Chino                2
# Catalão              1
# Name: count, dtype: int64

# %%
df1['room_type'].value_counts()
# Out:
# room_type
# T1    8854
# T0    8098
# T2    1874
# T3     636
# Name: count, dtype: int64

# %%
df1['distribuition'].value_counts()
# Out:
# distribuition
# Booking.com         6047
# Time-Share          2378
# Direto              1696
# RCI                  225
# d                    103
# Beguest.pt            28
# Booking.com B.V.       7
# F&B Team               7
# HK Team                6
# Hotelbeds Spain        1
# Name: count, dtype: int64

# %% [markdown]
# <h3 style="color: #7E5564;"> - Feature Selection (Dropping unnecesary features)</h3>

# %%
df1.sample(5)
# Out:
#                    resv_id  resv_date resv_status    checkin   checkout  rn  \
# 17676  A169-3114145349-792 2022-06-16   Cancelada 2022-07-12 2022-07-14   2
# 13306  A169-2761599143-244 2023-04-25        Paga 2023-04-29 2023-05-02   3
# 10348  16931145-1600855646 2022-12-12        Paga 2023-09-02 2023-09-09   7
# 196    A169-2363537352-855 2023-06-11        Paga 2023-06-22 2023-06-25   3
# 11694  14352161-1600855111 2022-03-07   Cancelada 2022-09-17 2022-09-24   7
#
#       resv_total  adults  child  baby room_type  id_roomtype  id_client  \
# 17676     217.56       4      0  <NA>        T1       328920   10271607
# 13306     191.58       2      1     0        T1       328918   14672013
# 10348      267.3       5      1     0        T2       328937    6083587
# 196       268.39       2      0     0        T1       419191   15516181
# 11694     213.78       1      0     0        T1       328961    6293458
#
#                    guest client_country guest_country  guest_language  \
# 17676  John Doe 10271607        Espanha       Espanha   Espanhol (ES)
# 13306  John coe 14672013       Portugal      Portugal  Português (PT)
# 10348   John 3oe 6083587       Portugal           NaN  Português (PT)
# 196    Lista de reservas      Argentina     Argentina  Português (PT)
# 11694   John doe 6293458       Portugal      Portugal  Português (PT)
#
#       distribuition  oos         other
# 17676   Booking.com  NaN  Reembolsável
# 13306   Booking.com  NaN           NaN
# 10348    Time-Share  NaN           NaN
# 196     Booking.com  NaN           NaN
# 11694    Time-Share  NaN           NaN

# %%
df1 = df1.drop(columns=['other'])
df1.head()
# Out:
#                resv_id  resv_date resv_status    checkin   checkout  rn  \
# 0  A169-2511331136-465 2023-08-08        Paga 2023-08-11 2023-08-13   2
# 1  A169-3087875980-637 2022-05-11        Paga 2022-06-03 2022-06-04   1
# 2  A169-3285564121-828 2022-05-15        Paga 2022-08-21 2022-08-24   3
# 3  A169-3703768823-172 2023-03-11        Paga 2023-03-17 2023-03-18   1
# 4  A169-4048298901-301 2023-09-25        Paga 2023-09-26 2023-09-30   4
#
#   resv_total  adults  child  baby room_type  id_roomtype  id_client  \
# 0     557.85       4      0     0        T1       328927   16843014
# 1      68.38       2      0     0        T1       328970    9602155
# 2     631.05       4      0     0        T3       328588    9646746
# 3      48.26       2      0     0        T0       328947   13951562
# 4     255.09       1      0     0        T0       328957   17813842
#
#                guest client_country  guest_country guest_language  \
# 0  Lista de reservas  África do Sul            NaN        Francês
# 1   John Doe 9602155  África do Sul  África do Sul    Inglês (UK)
# 2   John Doe 9646746  África do Sul  África do Sul    Inglês (UK)
# 3  Lista de reservas  África do Sul  África do Sul    Inglês (UK)
# 4  Lista de reservas  África do Sul  África do Sul    Inglês (UK)
#
#   distribuition  oos
# 0   Booking.com  NaN
# 1   Booking.com  NaN
# 2   Booking.com  NaN
# 3   Booking.com  NaN
# 4   Booking.com  NaN

# %% [markdown]
# <h3 style="color: #7E5564;"> - Checking Null Values</h3>

# %%
df1.isna().sum()
# Out:
# resv_id               0
# resv_date             0
# resv_status           0
# checkin               0
# checkout              0
# rn                    0
# resv_total            0
# adults                0
# child                 0
# baby               2560
# room_type             0
# id_roomtype           0
# id_client          1775
# guest                 0
# client_country     1828
# guest_country      3389
# guest_language     3102
# distribuition      3593
# oos               18479
# dtype: int64

# %% [markdown]
# <h3 style="color: #7E5564;"> - only need active reservations for RAG app</h3>

# %%
df1["resv_status"].value_counts()
# Out:
# resv_status
# Paga                         9272
# Cancelada                    7206
# De proprietário              1341
# Pré-reserva                   966
# Indisponível                  402
# Confirmada                    250
# Pedido informação              12
# Sob pedido                     10
# Pedido de disponibilidade       2
# Garantia                        1
# Name: count, dtype: int64

# %%
# Define the list of statuses to keep
rows_to_keep = ['Paga', 'Pré-reserva', 'Confirmada', 'Sob pedido']

# Filter the dataframe
df1 = df1[df1['resv_status'].isin(rows_to_keep)]


# Display the first few rows of the filtered dataframe
df1.sample(5)
# Out:
#                    resv_id  resv_date resv_status    checkin   checkout  rn  \
# 2000   A169-3668908396-976 2022-12-04        Paga 2022-12-07 2022-12-08   1
# 5852   11993280-1600858462 2021-02-23        Paga 2021-09-04 2021-09-11   7
# 13859  A169-3314238087-520 2021-05-13        Paga 2021-06-05 2021-06-11   6
# 1277   A169-2723276250-335 2023-05-09        Paga 2023-05-26 2023-05-31   5
# 14660  A169-4088469555-402 2023-10-06        Paga 2023-11-10 2023-11-13   3
#
#       resv_total  adults  child  baby room_type  id_roomtype  id_client  \
# 2000       27.05       2      0     0        T0       328951   12761654
# 5852       281.8       4      0     0        T1       328960    6270949
# 13859      305.4       4      0     0        T1       328960    6550480
# 1277      236.42       2      0     0        T0       328871   14926362
# 14660     110.29       1      0     0        T0       328890   18018834
#
#                    guest client_country guest_country  guest_language  \
# 2000   John Doe 12761654        Espanha       Espanha   Espanhol (ES)
# 5852    John doe 6270949       Portugal      Portugal  Português (PT)
# 13859   John poe 6550480       Portugal      Portugal  Português (PT)
# 1277   Lista de reservas        Espanha       Espanha   Espanhol (ES)
# 14660  Lista de reservas       Portugal      Portugal  Português (PT)
#
#       distribuition  oos
# 2000    Booking.com  NaN
# 5852     Time-Share  NaN
# 13859   Booking.com  NaN
# 1277    Booking.com  NaN
# 14660   Booking.com  NaN

# %% [markdown]
# <h3 style="color: #7E5564;"> - Drop OOS for RAG</h3>

# %%
df1 = df1.drop(columns=['oos'])
df1.head()
# Out:
#                resv_id  resv_date resv_status    checkin   checkout  rn  \
# 0  A169-2511331136-465 2023-08-08        Paga 2023-08-11 2023-08-13   2
# 1  A169-3087875980-637 2022-05-11        Paga 2022-06-03 2022-06-04   1
# 2  A169-3285564121-828 2022-05-15        Paga 2022-08-21 2022-08-24   3
# 3  A169-3703768823-172 2023-03-11        Paga 2023-03-17 2023-03-18   1
# 4  A169-4048298901-301 2023-09-25        Paga 2023-09-26 2023-09-30   4
#
#   resv_total  adults  child  baby room_type  id_roomtype  id_client  \
# 0     557.85       4      0     0        T1       328927   16843014
# 1      68.38       2      0     0        T1       328970    9602155
# 2     631.05       4      0     0        T3       328588    9646746
# 3      48.26       2      0     0        T0       328947   13951562
# 4     255.09       1      0     0        T0       328957   17813842
#
#                guest client_country  guest_country guest_language  \
# 0  Lista de reservas  África do Sul            NaN        Francês
# 1   John Doe 9602155  África do Sul  África do Sul    Inglês (UK)
# 2   John Doe 9646746  África do Sul  África do Sul    Inglês (UK)
# 3  Lista de reservas  África do Sul  África do Sul    Inglês (UK)
# 4  Lista de reservas  África do Sul  África do Sul    Inglês (UK)
#
#   distribuition
# 0   Booking.com
# 1   Booking.com
# 2   Booking.com
# 3   Booking.com
# 4   Booking.com

# %%
df1["resv_status"].value_counts()
# Out:
# resv_status
# Paga           9272
# Pré-reserva     966
# Confirmada      250
# Sob pedido       10
# Name: count, dtype: int64

# %%
df1['resv_status'] = df1['resv_status'].replace(rows_to_keep, 'Active')
df1['resv_status'].value_counts()
# Out:
# resv_status
# Active    10498
# Name: count, dtype: int64

# %%
df1.sample(5)
# Out:
#                    resv_id  resv_date resv_status    checkin   checkout  rn  \
# 10153  16926865-1600711473 2022-12-12      Active 2023-06-25 2023-07-02   7
# 16735  A169-4009768974-554 2024-01-05      Active 2024-02-24 2024-03-02   7
# 8143   14247955-1600858318 2022-02-22      Active 2022-02-24 2022-02-26   2
# 13589  A169-3054626008-440 2022-06-30      Active 2022-07-12 2022-07-16   4
# 4479   A169-4196749500-444 2024-01-19      Active 2024-08-15 2024-08-22   7
#
#       resv_total  adults  child  baby room_type  id_roomtype  id_client  \
# 10153     228.74       1      0     0        T1       328597    6292801
# 16735     209.67       2      0     0        T0       328890   19366554
# 8143       52.55       2      0     0        T0       328954    8701626
# 13589      297.6       2      0     0        T0       328951   10527295
# 4479     1196.97       4      0     0        T1       328597   19551461
#
#                    guest client_country guest_country  guest_language  \
# 10153  Lista de reservas       Portugal      Portugal  Português (PT)
# 16735  John Doe 19366554    Reino Unido   Reino Unido     Inglês (UK)
# 8143   Lista de reservas       Portugal      Portugal  Português (PT)
# 13589  John coe 10527295       Portugal      Portugal  Português (PT)
# 4479   John Doe 19551461        Irlanda       Irlanda     Inglês (UK)
#
#       distribuition
# 10153    Time-Share
# 16735   Booking.com
# 8143         Direto
# 13589   Booking.com
# 4479    Booking.com

# %%
df1.isna().sum()
# Out:
# resv_id             0
# resv_date           0
# resv_status         0
# checkin             0
# checkout            0
# rn                  0
# resv_total          0
# adults              0
# child               0
# baby               90
# room_type           0
# id_roomtype         0
# id_client           0
# guest               0
# client_country     67
# guest_country     227
# guest_language      0
# distribuition       0
# dtype: int64

# %%
nan_baby_rows = df1[df1['baby'].isna()]
nan_baby_rows
# Out:
#                    resv_id  resv_date resv_status    checkin   checkout  rn  \
# 180    A169-4186177977-177 2024-01-27      Active 2024-03-07 2024-03-09   2
# 512    A169-4269855282-232 2024-01-27      Active 2024-02-16 2024-02-18   2
# 637    A169-4157026145-474 2023-12-25      Active 2024-02-03 2024-02-04   1
# 638    A169-4157026145-483 2023-12-25      Active 2024-02-03 2024-02-04   1
# 693    A169-4119881264-718 2024-01-03      Active 2024-02-20 2024-02-24   4
# ...                    ...        ...         ...        ...        ...  ..
# 17084    A169-4248867841-2 2024-01-24      Active 2024-02-12 2024-02-16   4
# 17108  A169-4268894192-480 2024-01-22      Active 2024-07-26 2024-07-27   1
# 17119  A169-4273688803-289 2024-01-25      Active 2024-03-08 2024-03-10   2
# 17126  A169-4279276057-527 2024-01-09      Active 2024-03-08 2024-03-11   3
# 17142  A169-4287573866-318 2024-01-26      Active 2024-05-10 2024-05-12   2
#
#       resv_total  adults  child  baby room_type  id_roomtype  id_client  \
# 180        74.17       1      0  <NA>        T0       328891   19657750
# 512        65.09       2      0  <NA>        T0       429351   19662575
# 637        32.02       2      0  <NA>        T0       328947   19075527
# 638        97.87       5      1  <NA>        T3       328588   19075527
# 693       153.84       1      0  <NA>        T0       328885   19293705
# ...          ...     ...    ...   ...       ...          ...        ...
# 17084     115.53       1      1  <NA>        T0       328953   19623739
# 17108     437.11       3      5  <NA>        T3       328648   19587963
# 17119      96.57       3      0  <NA>        T1       328961   19638122
# 17126     274.98       8      0  <NA>        T3       328588   19407903
# 17142     221.96       2      0  <NA>        T2       328935   19648080
#
#                    guest client_country guest_country  guest_language  \
# 180    John Doe 19657750       Alemanha      Alemanha          Alemão
# 512    John Doe 19662575         Brasil        Brasil  Portugues (BR)
# 637    John Doe 19075527          China         China           Chino
# 638    John Doe 19075527          China         China           Chino
# 693    John Doe 19293705      Dinamarca     Dinamarca     Dinamarquês
# ...                  ...            ...           ...             ...
# 17084  John Doe 19623739    Reino Unido   Reino Unido     Inglês (UK)
# 17108  John Doe 19587963    Reino Unido   Reino Unido     Inglês (UK)
# 17119  John Doe 19638122    Reino Unido   Reino Unido     Inglês (UK)
# 17126  John Doe 19407903    Reino Unido   Reino Unido     Inglês (UK)
# 17142  John Doe 19648080    Reino Unido   Reino Unido     Inglês (UK)
#
#       distribuition
# 180     Booking.com
# 512     Booking.com
# 637     Booking.com
# 638     Booking.com
# 693     Booking.com
# ...             ...
# 17084   Booking.com
# 17108   Booking.com
# 17119   Booking.com
# 17126   Booking.com
# 17142   Booking.com
#
# [90 rows x 18 columns]

# %%
df1['baby'] = df1['baby'].fillna(0)
# df1.head()

# %%
df1.isna().sum()
# Out:
# resv_id             0
# resv_date           0
# resv_status         0
# checkin             0
# checkout            0
# rn                  0
# resv_total          0
# adults              0
# child               0
# baby                0
# room_type           0
# id_roomtype         0
# id_client           0
# guest               0
# client_country     67
# guest_country     227
# guest_language      0
# distribuition       0
# dtype: int64

# %%
df1.sample(8)
# Out:
#                    resv_id  resv_date resv_status    checkin   checkout  rn  \
# 17166  A169-2919102570-125 2021-08-24      Active 2021-08-26 2021-08-27   1
# 16655  A169-3927789285-291 2023-01-07      Active 2023-09-14 2023-09-17   3
# 16247  A169-3500950948-666 2023-04-29      Active 2023-05-12 2023-05-15   3
# 9797   16886271-1600708691 2022-12-06      Active 2023-06-11 2023-06-17   6
# 10284  16930158-1600855149 2022-12-12      Active 2023-06-04 2023-06-11   7
# 11890  20438223-1600855215 2023-11-07      Active 2024-07-06 2024-07-13   7
# 3181   A169-3796698697-336 2021-06-25      Active 2021-07-03 2021-07-08   5
# 12826  A169-2248737507-910 2022-05-16      Active 2022-07-11 2022-07-16   5
#
#       resv_total  adults  child  baby room_type  id_roomtype  id_client  \
# 17166      79.61       2      0     0        T0       328957    7375801
# 16655     209.43       2      0     0        T0       328952   13106881
# 16247     273.96       3      2     0        T2       328933   14750739
# 9797      356.41       1      0     0        T2       328587    6112420
# 10284     228.74       1      0     0        T1       328915    6295683
# 11890     222.26       1      0     0        T1       328924    6088363
# 3181       267.8       2      0     0        T0       328528    6844886
# 12826     548.95       2      0     0        T0       328874    9653909
#
#                    guest    client_country     guest_country  guest_language  \
# 17166   John Doe 7375801  República Tcheca  República Tcheca           Czech
# 16655  Lista de reservas       Reino Unido       Reino Unido     Inglês (UK)
# 16247  Lista de reservas       Reino Unido       Reino Unido     Inglês (UK)
# 9797    John soe 6112420          Portugal          Portugal  Português (PT)
# 10284   John qoe 6295683          Portugal          Portugal  Português (PT)
# 11890   John Soe 6088363          Portugal          Portugal  Português (PT)
# 3181   Lista de reservas            França            França         Francês
# 12826   John Doe 9653909          Portugal          Portugal  Português (PT)
#
#       distribuition
# 17166   Booking.com
# 16655   Booking.com
# 16247   Booking.com
# 9797     Time-Share
# 10284    Time-Share
# 11890    Time-Share
# 3181    Booking.com
# 12826   Booking.com

# %%
if 'guest_country' in df1.columns:
	nan_guest_country_rows = df1[df1['guest_country'].isna()]
	nan_guest_country_rows
else:
	print("Column 'guest_country' does not exist in the dataframe.")

# %%
df1['guest_country'] = df1['guest_country'].fillna(df1['client_country'])
df1.head()
# Out:
#                resv_id  resv_date resv_status    checkin   checkout  rn  \
# 0  A169-2511331136-465 2023-08-08      Active 2023-08-11 2023-08-13   2
# 1  A169-3087875980-637 2022-05-11      Active 2022-06-03 2022-06-04   1
# 2  A169-3285564121-828 2022-05-15      Active 2022-08-21 2022-08-24   3
# 3  A169-3703768823-172 2023-03-11      Active 2023-03-17 2023-03-18   1
# 4  A169-4048298901-301 2023-09-25      Active 2023-09-26 2023-09-30   4
#
#   resv_total  adults  child  baby room_type  id_roomtype  id_client  \
# 0     557.85       4      0     0        T1       328927   16843014
# 1      68.38       2      0     0        T1       328970    9602155
# 2     631.05       4      0     0        T3       328588    9646746
# 3      48.26       2      0     0        T0       328947   13951562
# 4     255.09       1      0     0        T0       328957   17813842
#
#                guest client_country  guest_country guest_language  \
# 0  Lista de reservas  África do Sul  África do Sul        Francês
# 1   John Doe 9602155  África do Sul  África do Sul    Inglês (UK)
# 2   John Doe 9646746  África do Sul  África do Sul    Inglês (UK)
# 3  Lista de reservas  África do Sul  África do Sul    Inglês (UK)
# 4  Lista de reservas  África do Sul  África do Sul    Inglês (UK)
#
#   distribuition
# 0   Booking.com
# 1   Booking.com
# 2   Booking.com
# 3   Booking.com
# 4   Booking.com

# %%
df1.columns
# Out:
# Index(['resv_id', 'resv_date', 'resv_status', 'checkin', 'checkout', 'rn',
#        'resv_total', 'adults', 'child', 'baby', 'room_type', 'id_roomtype',
#        'id_client', 'guest', 'client_country', 'guest_country',
#        'guest_language', 'distribuition'],
#       dtype='object')

# %%
df1.isna().sum()
# Out:
# resv_id            0
# resv_date          0
# resv_status        0
# checkin            0
# checkout           0
# rn                 0
# resv_total         0
# adults             0
# child              0
# baby               0
# room_type          0
# id_roomtype        0
# id_client          0
# guest              0
# client_country    67
# guest_country     65
# guest_language     0
# distribuition      0
# dtype: int64

# %%
df1.sample(8)
# Out:
#                    resv_id  resv_date resv_status    checkin   checkout  rn  \
# 16587  A169-3851593892-278 2023-02-03      Active 2023-04-25 2023-05-05  10
# 12169  20471755-1600855135 2023-11-11      Active 2024-10-20 2024-10-27   7
# 8446   14344072-1600855283 2022-03-06      Active 2022-08-07 2022-08-14   7
# 1757   A169-3347454208-873 2023-03-01      Active 2023-05-05 2023-05-07   2
# 4837   A169-4009817766-171 2023-09-22      Active 2023-09-22 2023-09-25   3
# 1920   A169-3563226737-520 2023-05-14      Active 2023-08-28 2023-08-31   3
# 12303  20645034-1600854200 2023-11-29      Active 2023-12-01 2024-01-01  31
# 14582  A169-4015162863-131 2023-11-24      Active 2023-11-25 2023-11-26   1
#
#       resv_total  adults  child  baby room_type  id_roomtype  id_client  \
# 16587     832.84       2      0     0        T1       395867   13449668
# 12169     222.26       1      0     0        T1       328918    5981974
# 8446      213.78       3      3     0        T1       328929    6285733
# 1757       91.12       2      0     0        T0       328956   13806037
# 4837      224.67       2      0     0        T1       328917   17776185
# 1920      392.58       2      0     0        T1       411967   15004069
# 12303     547.17       1      0     0        T0       328877    9073068
# 14582      32.09       2      0     0        T0       328885   18701312
#
#                    guest client_country guest_country  guest_language  \
# 16587  John poe 13449668    Reino Unido   Reino Unido     Inglês (UK)
# 12169  Lista de reservas       Portugal      Portugal  Português (PT)
# 8446   Lista de reservas       Portugal      Portugal  Português (PT)
# 1757   John Doe 13806037        Espanha       Espanha   Espanhol (ES)
# 4837   John Doe 17776185         Itália        Itália         Italian
# 1920   John Doe 15004069        Espanha       Espanha   Espanhol (ES)
# 12303   John Doe 9073068       Portugal      Portugal  Português (PT)
# 14582  John Doe 18701312       Portugal      Portugal  Português (PT)
#
#       distribuition
# 16587   Booking.com
# 12169    Time-Share
# 8446     Time-Share
# 1757    Booking.com
# 4837    Booking.com
# 1920    Booking.com
# 12303        Direto
# 14582   Booking.com

# %% [markdown]
# <h3 style="color: #7E5564;"> - Checking Duplicates</h3>

# %%
# Check for duplicate rows
duplicate_rows = df1.duplicated().sum()
duplicate_rows
# Out:
# 0

# %% [markdown]
# <h3 style="color: #7E5564;"> - Checking Emtpy Spaces</h3>

# %%
empty_spaces = df1.eq(' ').sum()
empty_spaces
# Out:
# resv_id           0
# resv_date         0
# resv_status       0
# checkin           0
# checkout          0
# rn                0
# resv_total        0
# adults            0
# child             0
# baby              0
# room_type         0
# id_roomtype       0
# id_client         0
# guest             0
# client_country    0
# guest_country     0
# guest_language    0
# distribuition     0
# dtype: Int64

# %%
df1.dtypes
# Out:
# resv_id                   object
# resv_date         datetime64[ns]
# resv_status               object
# checkin           datetime64[ns]
# checkout          datetime64[ns]
# rn                         Int64
# resv_total                object
# adults                     Int64
# child                      Int64
# baby                       Int64
# room_type                 object
# id_roomtype                Int64
# id_client                  Int64
# guest                     object
# client_country            object
# guest_country             object
# guest_language            object
# distribuition             object
# dtype: object

# %%
df1.to_csv('data_clean.csv', index=False)

# %%
df1.columns
# Out:
# Index(['resv_id', 'resv_date', 'resv_status', 'checkin', 'checkout', 'rn',
#        'resv_total', 'adults', 'child', 'baby', 'room_type', 'id_roomtype',
#        'id_client', 'guest', 'client_country', 'guest_country',
#        'guest_language', 'distribuition'],
#       dtype='object')

# %% [markdown]
# <h1 style="color: #6E9D8C;"> * III * Hotel Services df2 clean</h1>

# %% [markdown]
# <h3 style="color: #7E5564;"> - Checking Emtpy Spaces</h3>

# %%
df = df2.copy()

# %%
df['oos'].value_counts()
# Out:
# oos
# m              539
# h              344
# a               48
# t               46
# ADM              2
# Overbooking      1
# maintenance      1
# team             1
# hk               1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19462 entries, 0 to 19461
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   resv_id         19462 non-null  object
#  1   resv_date       19462 non-null  datetime64[ns]
#  2   resv_status     19462 non-null  object
#  3   checkin         19462 non-null  datetime64[ns]
#  4   checkout        19462 non-null  datetime64[ns]
#  5   rn              19462 non-null  Int64
#  6   resv_total      19462 non-null  object
#  7   adults          19462 non-null  Int64
#  8   child           19462 non-null  Int64
#  9   baby            16902 non-null  Int64
#  10  room_type       19462 non-null  object
#  11  id_roomtype     19462 non-null  Int64
#  12  id_client       17687 non-null  Int64
#  13  guest           19462 non-null  object
#  14  client_country  17634 non-null  object
#  15  guest_country   16073 non-null  object
#  16  guest_language  16360 non-null  object
#  17  distribuition   15869 non-null  object
#  18  oos             983 non-null    object
#  19  other           2151 non-null   object
# dtypes: Int64(6), datetime64[ns](3), object(11)
# memory usage: 3.1+ MB

# %%
df['resv_status'].value_counts()
# Out:
# resv_status
# Paga                         9272
# Cancelada                    7206
# De proprietário              1341
# Pré-reserva                   966
# Indisponível                  402
# Confirmada                    250
# Pedido informação              12
# Sob pedido                     10
# Pedido de disponibilidade       2
# Garantia                        1
# Name: count, dtype: int64

# %%
# Define the list of status to keep
rows_to_keep2 = ['Paga', 'Pré-reserva', 'Confirmada', 'Sob pedido', 'De proprietário']

# Filter the dataframe
df = df[df['resv_status'].isin(rows_to_keep2)]


df['resv_status'].value_counts()
# Out:
# resv_status
# Paga               9272
# De proprietário    1341
# Pré-reserva         966
# Confirmada          250
# Sob pedido           10
# Name: count, dtype: int64

# %%
df['resv_status'] = df['resv_status'].replace(['Paga', 'Pré-reserva', 'Confirmada', 'Sob pedido'], 'Active')
df['resv_status'].value_counts()
# Out:
# resv_status
# Active             10498
# De proprietário     1341
# Name: count, dtype: int64

# %%
df['resv_status'] = df['resv_status'].replace(['De proprietário'], 'Out_of_Service')
df['resv_status'].value_counts()
# Out:
# resv_status
# Active            10498
# Out_of_Service     1341
# Name: count, dtype: int64

# %%
df.sample(5)
# Out:
#                    resv_id  resv_date resv_status    checkin   checkout  rn  \
# 6258   12025137-1600855268 2021-03-03      Active 2021-08-22 2021-08-29   7
# 181    A169-4224675566-197 2023-11-27      Active 2023-12-17 2023-12-24   7
# 12988  A169-2408055309-163 2022-05-28      Active 2022-05-30 2022-06-03   4
# 3958   A169-3225010450-894 2022-03-24      Active 2022-07-11 2022-07-19   8
# 15726  A169-2909277509-649 2022-08-17      Active 2022-08-27 2022-08-29   2
#
#       resv_total  adults  child  baby room_type  id_roomtype  id_client  \
# 6258         210       2      2     0        T1       328927    6296245
# 181       230.05       2      0     0        T0       328890   18723647
# 12988     341.68       5      0     0        T2       328587    9890418
# 3958      543.03       2      0     0        T0       328950    9018901
# 15726     177.59       2      0     0        T0       328947   11534656
#
#                    guest client_country guest_country  guest_language  \
# 6258    John (oe 6296245       Portugal      Portugal  Português (PT)
# 181    John Doe 18723647       Alemanha           NaN          Alemão
# 12988   John toe 9890418       Portugal      Portugal  Português (PT)
# 3958   Lista de reservas        Irlanda       Irlanda     Inglês (UK)
# 15726  John Doe 11534656    Reino Unido   Reino Unido     Inglês (UK)
#
#       distribuition  oos other
# 6258     Time-Share  NaN   NaN
# 181     Booking.com  NaN   NaN
# 12988   Booking.com  NaN   NaN
# 3958    Booking.com  NaN   NaN
# 15726   Booking.com  NaN   NaN

# %%
df.isna().sum()
# Out:
# resv_id               0
# resv_date             0
# resv_status           0
# checkin               0
# checkout              0
# rn                    0
# resv_total            0
# adults                0
# child                 0
# baby                 90
# room_type             0
# id_roomtype           0
# id_client             0
# guest                 0
# client_country       67
# guest_country      1555
# guest_language     1327
# distribuition      1333
# oos               10856
# other             11669
# dtype: int64

# %%
df['baby'] = df['baby'].fillna(0)
# df1.head()

# %%
df['guest_country'] = df['guest_country'].fillna(df['client_country'])

# %%
columns_to_drop = ["resv_id", "resv_date", "guest", "client_country", "guest_language", "other"]
columns_to_drop = [col for col in columns_to_drop if col in df.columns]
df = df.drop(columns=columns_to_drop)
df.head()
# Out:
#   resv_status    checkin   checkout  rn resv_total  adults  child  baby  \
# 0      Active 2023-08-11 2023-08-13   2     557.85       4      0     0
# 1      Active 2022-06-03 2022-06-04   1      68.38       2      0     0
# 2      Active 2022-08-21 2022-08-24   3     631.05       4      0     0
# 3      Active 2023-03-17 2023-03-18   1      48.26       2      0     0
# 4      Active 2023-09-26 2023-09-30   4     255.09       1      0     0
#
#   room_type  id_roomtype  id_client  guest_country distribuition  oos
# 0        T1       328927   16843014  África do Sul   Booking.com  NaN
# 1        T1       328970    9602155  África do Sul   Booking.com  NaN
# 2        T3       328588    9646746  África do Sul   Booking.com  NaN
# 3        T0       328947   13951562  África do Sul   Booking.com  NaN
# 4        T0       328957   17813842  África do Sul   Booking.com  NaN

# %%
df['guest_country'] = df['guest_country'].fillna(0)
df['distribuition'] = df['distribuition'].fillna(0)
df['oos'] = df['oos'].fillna(0)

# %%
df['oos'].value_counts()
# Out:
# oos
# 0              10856
# m                539
# h                344
# a                 48
# t                 46
# ADM                2
# Overbooking        1
# maintenance        1
# team               1
# hk                 1
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# resv_status      0
# checkin          0
# checkout         0
# rn               0
# resv_total       0
# adults           0
# child            0
# baby             0
# room_type        0
# id_roomtype      0
# id_client        0
# guest_country    0
# distribuition    0
# oos              0
# dtype: int64

# %%
df.nunique()
# Out:
# resv_status         2
# checkin          1289
# checkout         1280
# rn                115
# resv_total       4738
# adults             11
# child               7
# baby                3
# room_type           4
# id_roomtype        94
# id_client        6815
# guest_country      81
# distribuition      11
# oos                10
# dtype: int64

# %%
df['oos'].value_counts()
# Out:
# oos
# 0              10856
# m                539
# h                344
# a                 48
# t                 46
# ADM                2
# Overbooking        1
# maintenance        1
# team               1
# hk                 1
# Name: count, dtype: int64

# %%
df['oos'] = df['oos'].replace('m', 'maint')
df['oos'] = df['oos'].replace('t', 'team')
df['oos'] = df['oos'].replace('a', 'admin')
df['oos'] = df['oos'].replace('ADM', 'admin')
df['oos'] = df['oos'].replace('h', 'hk')
df['oos'].value_counts()
# Out:
# oos
# 0              10856
# maint            539
# hk               345
# admin             50
# team              47
# Overbooking        1
# maintenance        1
# Name: count, dtype: int64

# %%
df.nunique().sort_values(ascending=False)
# Out:
# id_client        6815
# resv_total       4738
# checkin          1289
# checkout         1280
# rn                115
# id_roomtype        94
# guest_country      81
# adults             11
# distribuition      11
# child               7
# oos                 7
# room_type           4
# baby                3
# resv_status         2
# dtype: int64

# %%
df['resv_total'] = pd.to_numeric(df['resv_total'], errors='coerce')
df.dtypes
# Out:
# resv_status              object
# checkin          datetime64[ns]
# checkout         datetime64[ns]
# rn                        Int64
# resv_total              float64
# adults                    Int64
# child                     Int64
# baby                      Int64
# room_type                object
# id_roomtype               Int64
# id_client                 Int64
# guest_country            object
# distribuition            object
# oos                      object
# dtype: object

# %%
df.describe().T
# Out:
#                count                           mean                  min  \
# checkin        11839  2022-12-24 04:10:33.702170880  2020-08-08 00:00:00
# checkout       11839  2022-12-30 23:04:02.959709696  2020-08-15 00:00:00
# rn           11839.0                       6.787144                  1.0
# resv_total   11839.0                     220.109626                  0.0
# adults       11839.0                       2.011234                  1.0
# child        11839.0                       0.138948                  0.0
# baby         11839.0                       0.003885                  0.0
# id_roomtype  11839.0                  331186.777008             328528.0
# id_client    11839.0                 9736224.687474              91089.0
#
#                              25%                  50%                  75%  \
# checkin      2022-06-09 00:00:00  2023-01-27 00:00:00  2023-08-18 00:00:00
# checkout     2022-06-13 12:00:00  2023-01-31 00:00:00  2023-08-22 00:00:00
# rn                           2.0                  4.0                  7.0
# resv_total                66.225               185.55                288.7
# adults                       1.0                  2.0                  2.0
# child                        0.0                  0.0                  0.0
# baby                         0.0                  0.0                  0.0
# id_roomtype             328888.0             328929.0             328958.0
# id_client              6104850.0            9452791.0           13653914.5
#
#                              max            std
# checkin      2024-10-27 00:00:00            NaN
# checkout     2024-11-03 00:00:00            NaN
# rn                         267.0      13.684463
# resv_total               2675.78     222.537657
# adults                      12.0       1.297635
# child                        6.0       0.523678
# baby                         2.0       0.068669
# id_roomtype             440318.0    14181.30817
# id_client             19694730.0  5345439.63015

# %%
df.nunique().sort_values(ascending=False)
# Out:
# id_client        6815
# resv_total       4738
# checkin          1289
# checkout         1280
# rn                115
# id_roomtype        94
# guest_country      81
# adults             11
# distribuition      11
# child               7
# oos                 7
# room_type           4
# baby                3
# resv_status         2
# dtype: int64

# %%
df.oos.value_counts()
# Out:
# oos
# 0              10856
# maint            539
# hk               345
# admin             50
# team              47
# Overbooking        1
# maintenance        1
# Name: count, dtype: int64

# %%
df['oos'] = df['oos'].replace('admin', 'team')
df['oos'].value_counts()
# Out:
# oos
# 0              10856
# maint            539
# hk               345
# team              97
# Overbooking        1
# maintenance        1
# Name: count, dtype: int64

# %%
# deleting the rows with 'Overbooking' in the 'oos' column = 1row
df = df[df['oos'] != 'Overbooking']
df = df[df['oos'] != 'maintenance']
df = df[df['oos'] != 'maint']
df = df[df['oos'] != 'team']

# %%
df['oos'].value_counts()
# Out:
# oos
# 0     10856
# hk      345
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['resv_status', 'checkin', 'checkout', 'rn', 'resv_total', 'adults',
#        'child', 'baby', 'room_type', 'id_roomtype', 'id_client',
#        'guest_country', 'distribuition', 'oos'],
#       dtype='object')

# %%
df4 = df.copy()
df = df4.copy()

# %% [markdown]
# <h1 style="color: #6E9D8C;"> * IV * EDA (Exploratory Data Analysis)</h1>

# %% [markdown]
# <h3 style="color: #7E5564;"> - creating a new feature - full stay </h3>

# %%
df['hk_Full_stay'] = (df['rn'] // 8) + 1
df.sample(5)
# Out:
#       resv_status    checkin   checkout  rn  resv_total  adults  child  baby  \
# 3121       Active 2023-08-14 2023-08-20   6      832.80       2      2     0
# 13821      Active 2023-03-17 2023-03-18   1       60.10       4      0     0
# 5338       Active 2020-10-03 2020-10-06   3      101.25       2      0     0
# 2424       Active 2023-12-16 2023-12-17   1       89.87       7      0     0
# 3223       Active 2023-08-19 2023-08-21   2      237.82       1      0     0
#
#       room_type  id_roomtype  id_client guest_country distribuition oos  \
# 3121         T1       328597   13188953        França   Booking.com   0
# 13821        T1       328967   13488434      Portugal   Booking.com   0
# 5338         T0       328528    5974390      Portugal        Direto   0
# 2424         T3       328938   18778786       Espanha   Booking.com   0
# 3223         T0       328881   15488692        França   Booking.com   0
#
#        hk_Full_stay
# 3121              1
# 13821             1
# 5338              1
# 2424              1
# 3223              1

# %% [markdown]
# <h3 style="color: #7E5564;"> - changing categorical features into numerical</h3>

# %%
df['room_type'].value_counts()
# Out:
# room_type
# T1    5288
# T0    4388
# T2    1141
# T3     384
# Name: count, dtype: int64

# %%
room_type_mapping = {'T0': 0, 'T1': 1, 'T2': 2, 'T3': 3}
df['room_type'] = df['room_type'].map(room_type_mapping)
df['room_type'].value_counts()
# Out:
# room_type
# 1    5288
# 0    4388
# 2    1141
# 3     384
# Name: count, dtype: int64

# %%
df['resv_status'].value_counts()
# Out:
# resv_status
# Active            10498
# Out_of_Service      703
# Name: count, dtype: int64

# %%
reservation_status_mapping = {'Out_of_Service': 0, 'Active' : 1}
df['resv_status'] = df['resv_status'].map(reservation_status_mapping)
df['resv_status'].value_counts()
# Out:
# resv_status
# 1    10498
# 0      703
# Name: count, dtype: int64

# %%
df.head(3)
# Out:
#    resv_status    checkin   checkout  rn  resv_total  adults  child  baby  \
# 0            1 2023-08-11 2023-08-13   2      557.85       4      0     0
# 1            1 2022-06-03 2022-06-04   1       68.38       2      0     0
# 2            1 2022-08-21 2022-08-24   3      631.05       4      0     0
#
#    room_type  id_roomtype  id_client  guest_country distribuition oos  \
# 0          1       328927   16843014  África do Sul   Booking.com   0
# 1          1       328970    9602155  África do Sul   Booking.com   0
# 2          3       328588    9646746  África do Sul   Booking.com   0
#
#    hk_Full_stay
# 0             1
# 1             1
# 2             1

# %%
df = df.drop(columns=['checkin', 'resv_total', 'id_roomtype', 'guest_country', 'distribuition'])
df.head()
# Out:
#    resv_status   checkout  rn  adults  child  baby  room_type  id_client oos  \
# 0            1 2023-08-13   2       4      0     0          1   16843014   0
# 1            1 2022-06-04   1       2      0     0          1    9602155   0
# 2            1 2022-08-24   3       4      0     0          3    9646746   0
# 3            1 2023-03-18   1       2      0     0          0   13951562   0
# 4            1 2023-09-30   4       1      0     0          0   17813842   0
#
#    hk_Full_stay
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %%
df['checkout_year'] = df['checkout'].dt.year
df['checkout_month'] = df['checkout'].dt.month
df['checkout_day'] = df['checkout'].dt.day
df.head()
# Out:
#    resv_status   checkout  rn  adults  child  baby  room_type  id_client oos  \
# 0            1 2023-08-13   2       4      0     0          1   16843014   0
# 1            1 2022-06-04   1       2      0     0          1    9602155   0
# 2            1 2022-08-24   3       4      0     0          3    9646746   0
# 3            1 2023-03-18   1       2      0     0          0   13951562   0
# 4            1 2023-09-30   4       1      0     0          0   17813842   0
#
#    hk_Full_stay  checkout_year  checkout_month  checkout_day
# 0             1           2023               8            13
# 1             1           2022               6             4
# 2             1           2022               8            24
# 3             1           2023               3            18
# 4             1           2023               9            30

# %%
df['checkout_day_name'] = df['checkout'].dt.day_name()
df['checkout_day_name'].value_counts()
# Out:
# checkout_day_name
# Saturday     2889
# Sunday       2649
# Friday       1428
# Monday       1276
# Thursday      993
# Tuesday       986
# Wednesday     980
# Name: count, dtype: int64

# %%
day_mapping = {
    'Monday': 2,
    'Tuesday': 3,
    'Wednesday': 4,
    'Thursday': 5,
    'Friday': 6,
    'Saturday': 7,
    'Sunday': 1
}

df['checkout_day_name'] = df['checkout_day_name'].map(day_mapping)
df['checkout_day_name'].value_counts()
# Out:
# checkout_day_name
# 7    2889
# 1    2649
# 6    1428
# 2    1276
# 5     993
# 3     986
# 4     980
# Name: count, dtype: int64

# %%
df = df.drop(columns=['checkout']) # drop the original column checkout
df.sample(5)
# Out:
#        resv_status  rn  adults  child  baby  room_type  id_client oos  \
# 16038            1   5       2      0     0          1   15315004   0
# 5778             1   3       1      0     0          1    6270091   0
# 14495            1   3       1      1     0          0   13322271   0
# 12014            1   7       1      0     0          1    6285733   0
# 15791            1   3       1      0     0          0   13320778   0
#
#        hk_Full_stay  checkout_year  checkout_month  checkout_day  \
# 16038             1           2023               9            29
# 5778              1           2021               5            25
# 14495             1           2023               2             2
# 12014             1           2024               8            18
# 15791             1           2023               2             8
#
#        checkout_day_name
# 16038                  6
# 5778                   3
# 14495                  5
# 12014                  1
# 15791                  4

# %%
df['oos'].value_counts()
# Out:
# oos
# 0     10856
# hk      345
# Name: count, dtype: int64

# %%
oos_status_mapping = {'hk': 0, 0 : 1}
df['oos'] = df['oos'].map(oos_status_mapping)
df['oos'].value_counts()
# Out:
# oos
# 1    10856
# 0      345
# Name: count, dtype: int64

# %% [markdown]
# <h3 style="color: #7E5564;"> - creating a new feature - halfstay </h3>

# %%
df['hk_half_stay'] = ((df['rn'] // 4))/2
df.sample(5)
# Out:
#        resv_status  rn  adults  child  baby  room_type  id_client  oos  \
# 12149            1   4       4      0     0          2    5996616    1
# 5715             1   2       2      0     0          1    5996616    1
# 11526            1   4       1      0     0          1    5996616    1
# 7588             1   1       1      0     0          1    8046284    1
# 5677             1   1       1      0     0          0    5996616    1
#
#        hk_Full_stay  checkout_year  checkout_month  checkout_day  \
# 12149             1           2023              11            17
# 5715              1           2021               2            12
# 11526             1           2023               7             7
# 7588              1           2021              11            20
# 5677              1           2020              12            23
#
#        checkout_day_name  hk_half_stay
# 12149                  6           0.5
# 5715                   6           0.0
# 11526                  6           0.5
# 7588                   7           0.0
# 5677                   4           0.0

# %% [markdown]
# <h3 style="color: #7E5564;"> - creating a new feature - Total of HouseKeeping  </h3>

# %%
df['total_HK'] = df['hk_Full_stay'] + df['hk_half_stay']
df.head()
# Out:
#    resv_status  rn  adults  child  baby  room_type  id_client  oos  \
# 0            1   2       4      0     0          1   16843014    1
# 1            1   1       2      0     0          1    9602155    1
# 2            1   3       4      0     0          3    9646746    1
# 3            1   1       2      0     0          0   13951562    1
# 4            1   4       1      0     0          0   17813842    1
#
#    hk_Full_stay  checkout_year  checkout_month  checkout_day  \
# 0             1           2023               8            13
# 1             1           2022               6             4
# 2             1           2022               8            24
# 3             1           2023               3            18
# 4             1           2023               9            30
#
#    checkout_day_name  hk_half_stay  total_HK
# 0                  1           0.0       1.0
# 1                  7           0.0       1.0
# 2                  4           0.0       1.0
# 3                  7           0.0       1.0
# 4                  7           0.5       1.5

# %% [markdown]
# <h3 style="color: #7E5564;"> - create a copy on Tableaux </h3>

# %%
df.to_csv('EDA.csv', index=False)

# %%
df.sample(8)
# Out:
#        resv_status  rn  adults  child  baby  room_type  id_client  oos  \
# 6416             1   7       1      0     0          2    6299235    1
# 886              1   3       2      0     0          0   14452319    1
# 152              1   7       2      0     0          0   13166238    1
# 10249            1   7       1      0     0          2    6293826    1
# 17070            1   4       2      0     0          1   17672039    1
# 2007             1   5       2      0     0          0    9135895    1
# 3237             1   1       2      0     0          0   12756264    1
# 7267             1   2       1      0     0          0    6635759    1
#
#        hk_Full_stay  checkout_year  checkout_month  checkout_day  \
# 6416              1           2021               8             7
# 886               1           2023               4            23
# 152               1           2023               6            24
# 10249             1           2023               8            13
# 17070             1           2023              10            10
# 2007              1           2022               7            29
# 3237              1           2022              12            11
# 7267              1           2021               7            25
#
#        checkout_day_name  hk_half_stay  total_HK
# 6416                   7           0.5       1.5
# 886                    1           0.0       1.0
# 152                    7           0.5       1.5
# 10249                  1           0.5       1.5
# 17070                  3           0.5       1.5
# 2007                   6           0.5       1.5
# 3237                   1           0.0       1.0
# 7267                   1           0.0       1.0

# %% [markdown]
# <h3 style="color: #7E5564;"> - Statistical information </h3>

# %%
df.dtypes
# Out:
# resv_status            int64
# rn                     Int64
# adults                 Int64
# child                  Int64
# baby                   Int64
# room_type              int64
# id_client              Int64
# oos                    int64
# hk_Full_stay           Int64
# checkout_year          int32
# checkout_month         int32
# checkout_day           int32
# checkout_day_name      int64
# hk_half_stay         Float64
# total_HK             Float64
# dtype: object

# %%
Total_Services_HK = df.groupby('room_type')['total_HK'].sum()
Total_Services_HK
# Out:
# room_type
# 0    8082.5
# 1    7821.5
# 2    1637.0
# 3     521.0
# Name: total_HK, dtype: Float64

# %%
Total_fullstay_HK = df.groupby('room_type')['hk_Full_stay'].sum()
Total_fullstay_HK
# Out:
# room_type
# 0    5727
# 1    5811
# 2    1229
# 3     407
# Name: hk_Full_stay, dtype: Int64

# %%
Total_hk_half_stay = df.groupby('room_type')['hk_half_stay'].sum()
Total_hk_half_stay
# Out:
# room_type
# 0    2355.5
# 1    2010.5
# 2     408.0
# 3     114.0
# Name: hk_half_stay, dtype: Float64

# %%
df5 = df.copy()
df = df5.copy()

# %%
croosstab_total = pd.crosstab(df['total_HK'], df['room_type'])
croosstab_total
# Out:
# room_type     0     1    2    3
# total_HK
# 1.0        2124  2162  482  192
# 1.5        1656  2854  620  177
# 3.0         181   127   14    9
# 3.5          55    30    3    2
# 5.0          27     9    0    0
# 5.5          15     7    2    1
# 7.0          12    12    4    0
# 7.5         304    82   13    2
# 9.0           8     2    0    1
# 9.5           2     1    1    0
# 11.0          0     0    1    0
# 13.0          1     0    0    0
# 15.0          2     0    0    0
# 15.5          0     1    1    0
# 23.5          1     0    0    0
# 67.0          0     1    0    0

# %%
croosstab_total.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Crosstab of Room Type and Total Housekeeping')
plt.xlabel('Room Type')
plt.ylabel('Total Housekeeping')
plt.legend(title='Total HK', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
df.columns
# Out:
# Index(['resv_status', 'rn', 'adults', 'child', 'baby', 'room_type',
#        'id_client', 'oos', 'hk_Full_stay', 'checkout_year', 'checkout_month',
#        'checkout_day', 'checkout_day_name', 'hk_half_stay', 'total_HK'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                      count             mean            std      min  \
# resv_status        11201.0         0.937238       0.242546      0.0
# rn                 11201.0           5.4005       6.430364      1.0
# adults             11201.0          2.06803       1.310948      1.0
# child              11201.0         0.146683       0.537022      0.0
# baby               11201.0         0.004107       0.070591      0.0
# room_type          11201.0          0.77868       0.762769      0.0
# id_client          11201.0  10285499.333095  4960078.58772  91089.0
# oos                11201.0         0.969199       0.172785      0.0
# hk_Full_stay       11201.0         1.176145       0.724906      1.0
# checkout_year      11201.0      2022.528792       0.915782   2020.0
# checkout_month     11201.0         6.644764       2.955013      1.0
# checkout_day       11201.0        14.917597       9.094459      1.0
# checkout_day_name  11201.0         4.092045       2.363073      1.0
# hk_half_stay       11201.0          0.43639       0.787255      0.0
# total_HK           11201.0         1.612535       1.492688      1.0
#
#                          25%        50%         75%         max
# resv_status              1.0        1.0         1.0         1.0
# rn                       2.0        4.0         7.0       267.0
# adults                   1.0        2.0         2.0        12.0
# child                    0.0        0.0         0.0         6.0
# baby                     0.0        0.0         0.0         2.0
# room_type                0.0        1.0         1.0         3.0
# id_client          6272913.0  9724005.0  13791006.0  19694730.0
# oos                      1.0        1.0         1.0         1.0
# hk_Full_stay             1.0        1.0         1.0        34.0
# checkout_year         2022.0     2023.0      2023.0      2024.0
# checkout_month           5.0        7.0         9.0        12.0
# checkout_day             7.0       15.0        23.0        31.0
# checkout_day_name        2.0        4.0         7.0         7.0
# hk_half_stay             0.0        0.5         0.5        33.0
# total_HK                 1.0        1.5         1.5        67.0

# %%
total_hk_by_year = df.groupby('checkout_year')['total_HK'].sum()
total_hk_by_year.plot(kind='bar', figsize=(10, 6))
plt.title('Total Housekeeping Services by Year')
plt.xlabel('Year')
plt.ylabel('Total Housekeeping Services')
plt.show()

# %% [markdown]
# <h3 style="color: #7E5564;"> - Checking Distributions</h3>

# %%
color = '#1f77b4'

# grid size
nrows, ncols = 5, 4  # adjust for your number of features

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(20, 16))

axes = axes.flatten()

# Plot each numerical feature
for i, ax in enumerate(axes):
    if i >= len(df.columns):
        ax.set_visible(False)  # hide unesed plots
        continue
    ax.hist(df.iloc[:, i], bins=30, color=color, edgecolor='black')
    ax.set_title(df.columns[i])

plt.tight_layout()
plt.show()

# %%
color = '#1f77b4'

# grid size
nrows, ncols = 5, 4 

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15, 10))

axes = axes.flatten()

for i, ax in enumerate(axes):
    if i >= len(df.columns):
        ax.set_visible(False)
        continue
    ax.boxplot(df.iloc[:, i].dropna(), vert=False, patch_artist=True, 
               boxprops=dict(facecolor=color, color='black'), 
               medianprops=dict(color='yellow'), whiskerprops=dict(color='black'), 
               capprops=dict(color='black'), flierprops=dict(marker='o', color='red', markersize=5))
    ax.set_title(df.columns[i], fontsize=10)
    ax.tick_params(axis='x', labelsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3 style="color: #7E5564;"> - Looking for Correlations</h3>

# %%
num = df.select_dtypes(include="number")
num.corr()["total_HK"].sort_values(ascending=False)
# Out:
# total_HK             1.000000
# hk_half_stay         0.988149
# hk_Full_stay         0.986008
# rn                   0.971654
# checkout_year        0.088207
# oos                  0.048232
# checkout_day_name    0.036854
# checkout_month      -0.002626
# baby                -0.010318
# child               -0.050501
# room_type           -0.110259
# id_client           -0.159585
# adults              -0.161237
# checkout_day        -0.187876
# resv_status         -0.264344
# Name: total_HK, dtype: float64

# %%
# Calculate the correlation matrix
num_corr = num.corr()

# Correlation Matrix-Heatmap Plot
mask = np.zeros_like(num_corr)
mask[np.triu_indices_from(mask)] = True # optional, to hide repeat half of the matrix

f, ax = plt.subplots(figsize=(10, 7))
sns.set(font_scale= 1) # increase font size

ax = sns.heatmap(num_corr, mask=mask, annot=True, annot_kws={"size": 12}, linewidths=.5, cmap="coolwarm", fmt=".2f", ax=ax) # round to 2 decimal places
ax.set_title("Multicollinearity", fontsize=18) # add title
plt.show()

# %%
df.columns
# Out:
# Index(['resv_status', 'rn', 'adults', 'child', 'baby', 'room_type',
#        'id_client', 'oos', 'hk_Full_stay', 'checkout_year', 'checkout_month',
#        'checkout_day', 'checkout_day_name', 'hk_half_stay', 'total_HK'],
#       dtype='object')

# %%
df.head()
df = df.drop(columns=['hk_half_stay', 'hk_Full_stay'])
df.columns
# Out:
# Index(['resv_status', 'rn', 'adults', 'child', 'baby', 'room_type',
#        'id_client', 'oos', 'checkout_year', 'checkout_month', 'checkout_day',
#        'checkout_day_name', 'total_HK'],
#       dtype='object')

# %% [markdown]
# <h1 style="color: #6E9D8C;"> * IV * Data Processing</h1>

# %% [markdown]
# <h3 style="color: #7E5564;"> - Normalizing the Data</h3>

# %%
df = df.drop(columns=['rn'])
df.columns
# Out:
# Index(['resv_status', 'adults', 'child', 'baby', 'room_type', 'id_client',
#        'oos', 'checkout_year', 'checkout_month', 'checkout_day',
#        'checkout_day_name', 'total_HK'],
#       dtype='object')

# %%
num2 = df.select_dtypes(include="number")
num2.corr()["total_HK"].sort_values(ascending=False)
# Out:
# total_HK             1.000000
# checkout_year        0.088207
# oos                  0.048232
# checkout_day_name    0.036854
# checkout_month      -0.002626
# baby                -0.010318
# child               -0.050501
# room_type           -0.110259
# id_client           -0.159585
# adults              -0.161237
# checkout_day        -0.187876
# resv_status         -0.264344
# Name: total_HK, dtype: float64

# %%
# Calculate the correlation matrix
num_corr2 = num2.corr()

# Correlation Matrix-Heatmap Plot
mask = np.zeros_like(num_corr2)
mask[np.triu_indices_from(mask)] = True # optional, to hide repeat half of the matrix

f, ax = plt.subplots(figsize=(10, 7))
sns.set(font_scale=1) # increase font size

ax = sns.heatmap(num_corr2, mask=mask, annot=True, annot_kws={"size": 12}, linewidths=.5, cmap="coolwarm", fmt=".2f", ax=ax) # round to 2 decimal places
ax.set_title("Multicollinearity without high correlarion features", fontsize=16) # add title
plt.show()

# %% [markdown]
# <h1 style="color: #6E9D8C;"> * V * Modeling</h1>

# %%
### Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression 
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
import xgboost as xgb
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import roc_curve, confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report

# %% [markdown]
# <h3 style="color: #7E5564;"> - Train-Test Split</h3>

# %%
X = df.drop("total_HK", axis=1)
y = df["total_HK"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f'100% of our data: {len(df)}.')
print(f'70% for training data: {len(X_train)}.')
print(f'30% for test data: {len(X_test)}.')
# Out:
# 100% of our data: 11201.
# 70% for training data: 7840.
# 30% for test data: 3361.

# %% [markdown]
# <h3 style="color: #7E5564;"> - Model Validation</h3>

# %%
# Train the model
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)

# %%
r2_3 = r2_score(y_test, predictions)
import numpy as np

MSE_3 = mean_squared_error(y_test, predictions)
RMSE_3 = np.sqrt(MSE_3)
MSE_3 = mean_squared_error(y_test, predictions)
MAE_3 = mean_absolute_error(y_test, predictions)
#Printing the results
print("R2 = ", round(r2_3, 4))
print("RMSE = ", round(RMSE_3, 2))
print("MSE =  ", round(MSE_3, 2)) 
print("MAE = ", round(MAE_3, 2))
# Out:
# R2 =  0.1538
# RMSE =  1.65
# MSE =   2.73
# MAE =  0.64

# %% [markdown]
# <h3 style="color: #7E5564;"> - Decision tree Model</h3>

# %%
tree = DecisionTreeRegressor()
tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
predictions_tree = tree.predict(X_test)

r2_3_4 = r2_score(y_test, predictions_tree)
MSE_3_4 = mean_squared_error(y_test, predictions_tree)
RMSE_3_4 = np.sqrt(MSE_3_4)
MAE_3_4 = mean_absolute_error(y_test, predictions_tree)

#Printing the results
print("R2 = ", round(r2_3_4, 4))
print("RMSE = ", round(RMSE_3_4, 4))
print("The value of the metric MSE is ", round(MSE_3_4, 4))
print("MAE = ", round(MAE_3_4, 4))
# Out:
# R2 =  0.2366
# RMSE =  1.5705
# The value of the metric MSE is  2.4664
# MAE =  0.3911

# %% [markdown]
# <h3 style="color: #7E5564;"> - Decision tree Model</h3>

# %%
import xgboost as xgb

xgbr = xgb.XGBRFRegressor()
xgbr.fit(X_train, y_train)

predictions_xgb = xgbr.predict(X_test)

# %%
r2_xgb = r2_score(y_test, predictions_xgb)
RMSE_xgb = mean_squared_error(y_test, predictions_xgb, squared=False) 
MSE_xgb = mean_squared_error(y_test, predictions_xgb)
MAE_xgb = mean_absolute_error(y_test, predictions_xgb)

#Printing the results
print("R2 = ", round(r2_xgb, 4))
print("RMSE = ", round(RMSE_xgb, 4))
print("The value of the metric MSE is ", round(MSE_xgb, 4))
print("MAE = ", round(MAE_xgb, 4))
# Out:
# R2 =  0.3466
# RMSE =  1.4529
# The value of the metric MSE is  2.1109
# MAE =  0.4127

# %% [markdown]
# <h1 style="color: #6E9D8C;"> * VI * Improving the Model</h1>

# %% [markdown]
# <h3 style="color: #7E5564;"> - removing outliers</h3>

# %%
def outlier_slayer(df): 
    """
    Automatically removes outliers based on Q1, Q3
    """
    for column in df.select_dtypes(include=[np.number]):
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR 
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df

# %%
df = outlier_slayer(df)

# %%
X = df.drop("total_HK", axis=1)
y = df["total_HK"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f'100% of our data: {len(df)}.')
print(f'70% for training data: {len(X_train)}.')
print(f'30% for test data: {len(X_test)}.')
# Out:
# 100% of our data: 7227.
# 70% for training data: 5058.
# 30% for test data: 2169.

# %%
xgbr2 = xgb.XGBRFRegressor()
xgbr2.fit(X_train, y_train)

predictions_xgb2 = xgbr2.predict(X_test)

# %%
r2_xgb = r2_score(y_test, predictions_xgb2)
RMSE_xgb = mean_squared_error(y_test, predictions_xgb2, squared=False) 
MSE_xgb = mean_squared_error(y_test, predictions_xgb2)
MAE_xgb = mean_absolute_error(y_test, predictions_xgb2)

#Printing the results
print("R2 = ", round(r2_xgb, 4))
print("RMSE = ", round(RMSE_xgb, 4))
print("The value of the metric MSE is ", round(MSE_xgb, 4))
print("MAE = ", round(MAE_xgb, 4))
# Out:
# R2 =  0.3355
# RMSE =  0.2021
# The value of the metric MSE is  0.0408
# MAE =  0.1657

# %% [markdown]
# <h1 style="color: #6E9D8C;"> * VII * Reporting</h1>

# %% [markdown]
# <h3 style="color: #7E5564;"> - removing outliers</h3>

# %%
# Ensure predictions are made on the correct test set
predictions_xgb = xgbr.predict(X_test)

# Create the evaluation dataframe
evaluation_df = pd.DataFrame({"actual": y_test, "pred": predictions_xgb})
evaluation_df
# Out:
#        actual      pred
# 4910      1.5  1.450829
# 16956     1.5  1.561129
# 11750     1.5  1.479708
# 13045     1.0  1.423664
# 3131      1.0  1.372407
# ...       ...       ...
# 8076      1.5  1.453397
# 6684      1.5  1.453397
# 6589      1.0  1.423208
# 698       1.0  1.562034
# 11830     1.5  1.511369
#
# [2169 rows x 2 columns]

# %%
evaluation_df["diference"] = abs(evaluation_df["actual"]-evaluation_df["pred"])
evaluation_df.sample(8)
# Out:
#        actual      pred  diference
# 15400     1.5  1.417567   0.082433
# 12252     1.5  1.500530    0.00053
# 15384     1.5  1.294523   0.205477
# 17313     1.0  1.402069   0.402069
# 3981      1.5  1.419119   0.080881
# 12579     1.5  1.744617   0.244617
# 485       1.5  1.563400     0.0634
# 7923      1.5  1.452239   0.047761

# %%
import seaborn as sns

scatter_color = "#2ab02f"
import matplotlib.pyplot as plt

scatter_color = "#2ab02f"
line_color = "#FF8C00"

plt.figure(figsize=(10, 6))

sns.regplot(x='actual', y='pred', data=evaluation_df,
            scatter_kws={"color": scatter_color, "alpha": 0.7},
            line_kws={"color": line_color, "linewidth": 3})

plt.ylim(bottom=0)
plt.title('Actual vs. Predicted Values', fontsize=16)
plt.xlabel('Actual', fontsize=14)
plt.ylabel('Predictions', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)
plt.show()
